# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import os


# %matplotlib inline

# %%
data_dir = "C:/Users/Kelvin Chumbe/Downloads/Datasets/Capstone_Twitter Modelling Datasets/Disaster Tweets Combined"

# %%
# Read in the data
tweets = pd.read_csv(os.path.join(data_dir, 'disaster_tweets.csv'))

# %%
tweets.head(2)
# Out:
#                     ID                                              Tweet  \
# 0  383600460340666369'  RT @Faiz_Baluch: #BalochistanEarthQuake Pakist...
# 1  383790723222364161'  #Earthquake 2013-09-28 02:39:43 (M5.0) EAST OF...
#
#                       Label
# 0  other_useful_information
# 1  other_useful_information

# %%
# Shape of the data
tweets.shape
# Out:
# (71154, 3)

# %%
# Look at some summary statistics about the data
tweets.describe()
# Out:
#                           ID  \
# count                  71141
# unique                 71118
# top     '541498918375141376'
# freq                       2
#
#                                                     Tweet  \
# count                                               71142
# unique                                              68055
# top     RT @ddlovato: So sad to hear about the nightcl...
# freq                                                  108
#
#                            Label
# count                      71141
# unique                        62
# top     Other Useful Information
# freq                        7625

# %% [markdown]
# #### **Observation**
# * There are duplicate IDs
# * There are duplicate tweets
# * Shape of the data is not similar to the counts of the tweets (Might indicate presence of null observations)

# %%
# Look at the dtypes of the data and their counts
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71154 entries, 0 to 71153
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      71141 non-null  object
#  1   Tweet   71142 non-null  object
#  2   Label   71141 non-null  object
# dtypes: object(3)
# memory usage: 1.6+ MB

# %%
# Check for null values
tweets.isnull().sum()
# Out:
# ID       13
# Tweet    12
# Label    13
# dtype: int64

# %%
# Drop any null rows or rows with a null feature
tweets = tweets.dropna(axis=0)

# %%
tweets.shape
# Out:
# (71141, 3)

# %%
# Confirm there's no nulls in the data
tweets.isnull().sum()
# Out:
# ID       0
# Tweet    0
# Label    0
# dtype: int64

# %%
# Check for the duplicated IDs 
tweets[tweets['ID'].duplicated(keep='first')]
# Out:
#                            ID  \
# 20599    '541249463734370304'
# 20942    '541316404847591424'
# 21227    '541378350053208064'
# 21353    '541391184216592385'
# 22051    '541455987543379968'
# 22159    '541460791589748736'
# 22188    '541462559182700544'
# 22564    '541483446133350401'
# 22823    '541498918375141376'
# 23031    '541513820598853634'
# 30955    '591920044579233792'
# 40004     451325112906940416'
# 40458     451884685636161536'
# 40983     453888740034109441'
# 41009     453947292819922945'
# 42639             2.43374e+17
# 42739  2.4338187159197286e+17
# 45413             2.07546e+17
# 56451   3.544394708016169e+17
# 59082             4.07147e+17
# 62862             4.02703e+17
# 71083       76683453143318400
# 71142       72726026563751904
#
#                                                    Tweet  \
# 20599               Power is out again in Banawa #RubyPH
# 20942  Typhoon #Hagupit "#Ruby" #Philippines http://t...
# 21227  Praying for everyones safety. �__F�__F�__F #Ru...
# 21353  True! #PrayHarderAndBeSafe #RubyPh http://t.co...
# 22051  http://t.co/hICUn1n1c3 Prayers for my Cousin J...
# 22159  Bed weather is bed weather #RubyPH �__8�__4�_�...
# 22188  @UNDP:���@abcnews:At least two dead in #borong...
# 22564  #RubyPH overtake power lines as well, not one ...
# 22823  "@TagaLPU: #WalangPasok December 8, 2014 ALL L...
# 23031  I guess #hagupit can't beat ondoy or yolanda #...
# 30955  Nepal #earthquake looks very terrible..hope th...
# 40004  In any other paÌ_s, a 8.2 earthquake estarÌ_a ...
# 40458  "The earthquake caused no deaths. There are mi...
# 40983  it is exciting to see that truck to get #iquiq...
# 41009  With contributions from mining and themselves,...
# 42639  RT @Ricbelon: Tsunami warning includes Colombi...
# 42739  RT @NBCNews: BREAKING: Major quake hits near C...
# 45413  Double quake highlights Italy's seismic perils...
# 56451  Pretty scary, the events of the last few days....
# 59082  RT @Christie_x: sooo much horrible stuff happe...
# 62862  Apocalyptic' Storm Floods Sardinia, 14 Dead: '...
# 71083  Client responded to a billing statement saying...
# 71142  #Joplin NORMLÃ¢â‚¬â„¢s Kelly Maddy loses #Miss...
#
#                                              Label
# 20599                              Not Informative
# 20942                              Not Informative
# 21227                              Not Informative
# 21353                              Not Informative
# 22051                              Not Informative
# 22159                              Not Informative
# 22188                              Not Informative
# 22564                   Other Relevant Information
# 22823                              Not Informative
# 23031                              Not Informative
# 30955               Sympathy and emotional support
# 40004                             Injured and dead
# 40458                     Other useful information
# 40983  Donations of supplies and/or volunteer work
# 41009  Donations of supplies and/or volunteer work
# 42639                           Caution and advice
# 42739                           Caution and advice
# 45413                     Other Useful Information
# 56451                     Other Useful Information
# 59082                         Sympathy and support
# 62862                         Affected individuals
# 71083                                       Damage
# 71142                                       Damage

# %%
# Drop duplicated ID
duplicated_ids = tweets[tweets['ID'].duplicated(keep='first')].index
tweets = tweets.drop(duplicated_ids, axis=0)

# %%
tweets.shape
# Out:
# (71118, 3)

# %%
# Check for tweets with duplicated text
tweets[tweets['Tweet'].duplicated(keep=False)]
# Out:
#                         ID                                              Tweet  \
# 2712   505229158327148546'  Violent quake rocks Bay Area: Are more aftersh...
# 2784   503870731831111680'  Strong 6.0 #California #EarthQuake Surprises a...
# 2992   504284375115370496'  Earthquake Warning Systems Exist. But Californ...
# 3067   503903767750651904'  California hit with worst quake in 25 years: N...
# 6136   451470880778878976'  Chile earthquake: rush to evacuate coast after...
# ...                    ...                                                ...
# 71082    72932164118908800   @andersoncooper: I took this earlier. Cross s...
# 71092    77578899676069600   @weatherchannel: Sad news to report. 3 more p...
# 71103    77558589681708800   @weatherchannel: Sad news to report. 3 more p...
# 71111    72646038405660608   @NBCActionNews: 89 confirmed deaths in #Jopli...
# 71115    72611686779072400   @NBCActionNews: 89 confirmed deaths in #Jopli...
#
#                                      Label
# 2712              other_useful_information
# 2784              other_useful_information
# 2992              other_useful_information
# 3067   infrastructure_and_utilities_damage
# 6136              other_useful_information
# ...                                    ...
# 71082                               Damage
# 71092                             Casualty
# 71103                             Casualty
# 71111                             Casualty
# 71115                             Casualty
#
# [4596 rows x 3 columns]

# %% [markdown]
# #### **Observations**
# * Duplicated tweets with different IDs may be due to retweets or reposts of the tweets. They should be removed

# %%
# Drop instances of duplicated tweets
duplicated_tweets_idx = tweets[tweets['Tweet'].duplicated(keep='first')].index
tweets = tweets.drop(duplicated_tweets_idx, axis=0)

# %%
tweets.shape
# Out:
# (68045, 3)

# %%
# Look the the unique labels/ categories of tweets and their count
tweets['Label'].unique(), len(tweets['Label'].unique())
# Out:
# (array(['other_useful_information',
#         'donation_needs_or_offers_or_volunteering_services',
#         'not_related_or_irrelevant', 'injured_or_dead_people',
#         'sympathy_and_emotional_support', 'caution_and_advice',
#         'infrastructure_and_utilities_damage',
#         'displaced_people_and_evacuations',
#         'missing_trapped_or_found_people', 'Infrastructure and utilities',
#         'Other relevant information', 'Not related or irrelevant',
#         'Injured or dead people', 'Sympathy and emotional support',
#         'Caution and advice', 'Personal updates', 'Money',
#         'Personal updates, sympathy, support', 'Other useful information',
#         'Injured and dead', 'Donations of money', 'Infrastructure',
#         'Needs of those affected', 'Displaced people',
#         'Shelter and supplies', 'Not related to crisis', 'Informative',
#         'Not informative', 'Non-government', 'Not Informative',
#         'Requests for Help/Needs', 'Other Relevant Information',
#         'Infrastructure Damage', 'Humanitarian Aid Provided',
#         'Volunteer or professional services',
#         'Missing, trapped, or found people', 'Other relevant',
#         'Not relevant', 'Response efforts', 'Infrastructure damage',
#         'Response Efforts', 'Not Relevant', 'Urgent Needs',
#         'Animal management', 'People missing or found',
#         'Donations of supplies and/or volunteer work', 'Not labeled',
#         'Other Useful Information', 'Affected individuals',
#         'Donations and volunteering', 'Sympathy and support',
#         'Not applicable', 'Donations of money, goods or services',
#         'Information Source', 'Unknown', 'Casualty', 'Damage', 'Donations',
#         'Caution and Advice', 'Search and Rescue', 'Information source',
#         'People missing, found or seen'], dtype=object),
#  62)

# %%
# Read category mappings file to map tweet labels to their respective categories
mappings_file = os.path.join(data_dir, 'Tweet_Category_Mappings.txt')
mappings_dict = {}

with open(mappings_file, 'r') as file:    
    while True: 
        line = file.readline()
        
        if line != '':
            arr = line.split('\t')
            mappings_dict[arr[0]] = arr[1].strip('\n')
        else:
            break
    
mappings_dict
# Out:
# {'donation_needs_or_offers_or_volunteering_services': 'Relief Request and Donations',
#  'injured_or_dead_people': 'Casualty',
#  'sympathy_and_emotional_support': 'Sympathy and Support',
#  'caution_and_advice': 'Caution and Advice',
#  'infrastructure_and_utilities_damage': 'Damage Report',
#  'displaced_people_and_evacuations': 'Search and Rescue',
#  'missing_trapped_or_found_people': 'Search and Rescue',
#  'Infrastructure and utilities': 'Damage Report',
#  'Injured or dead people': 'Casualty',
#  'Sympathy and emotional support': 'Sympathy and Support',
#  'Caution and advice': 'Caution and Advice',
#  'Money': 'Relief Request and Donations',
#  'Personal updates, sympathy, support': 'Sympathy and Support',
#  'Injured and dead': 'Casualty',
#  'Donations of money': 'Relief Request and Donations',
#  'Infrastructure': 'Damage Report',
#  'Needs of those affected': 'Relief Request and Donations',
#  'Displaced people': 'Search and Rescue',
#  'Shelter and supplies': 'Relief Request and Donations',
#  'Requests for Help/Needs': 'Relief Request and Donations',
#  'Infrastructure Damage': 'Damage Report',
#  'Humanitarian Aid Provided': 'Relief Request and Donations',
#  'Volunteer or professional services': 'Relief Request and Donations',
#  'Missing, trapped, or found people': 'Search and Rescue',
#  'Infrastructure damage': 'Damage Report',
#  'Urgent Needs': 'Relief Request and Donations',
#  'People missing or found': 'Search and Rescue',
#  'Donations of supplies and/or volunteer work': 'Relief Request and Donations',
#  'Affected individuals': 'Casualty',
#  'Donations and volunteering': 'Relief Request and Donations',
#  'Sympathy and support': 'Sympathy and Support',
#  'Donations of money, goods or services': 'Relief Request and Donations',
#  'Casualty': 'Casualty',
#  'Damage': 'Damage Report',
#  'Donations': 'Relief Request and Donations',
#  'Caution and Advice': 'Caution and Advice',
#  'Search and Rescue': 'Search and Rescue',
#  'People missing, found or seen': 'Search and Rescue'}

# %%
# Convert tweet labels using the mappings dictionary to the relevant categories
def map_label_category(label):
    return mappings_dict.get(label, None)    # Return None for labels not present in the dictionary
    

tweets['Category'] = tweets['Label'].apply(lambda x: map_label_category(x))

# %%
tweets.head()
# Out:
#                     ID                                              Tweet  \
# 0  383600460340666369'  RT @Faiz_Baluch: #BalochistanEarthQuake Pakist...
# 1  383790723222364161'  #Earthquake 2013-09-28 02:39:43 (M5.0) EAST OF...
# 2  384232048124518400'  #earthquake M2.2: Puerto Rico region http://t....
# 3  384860484643475456'  #PAKISTAN: #NASA releases images of Pakistan's...
# 4  383407962619772928'  【#USGS #alert】 M 1.5, Central Alaska: Septembe...
#
#                       Label Category
# 0  other_useful_information     None
# 1  other_useful_information     None
# 2  other_useful_information     None
# 3  other_useful_information     None
# 4  other_useful_information     None

# %%
# Look at the count of unique values in the category column
tweets['Category'].value_counts()
# Out:
# Casualty                        7465
# Sympathy and Support            7043
# Relief Request and Donations    6227
# Caution and Advice              4077
# Damage Report                   3918
# Search and Rescue               1126
# Name: Category, dtype: int64

# %%
# Check for None values in the categories column 
tweets['Category'].isnull().sum()
# Out:
# 38189

# %%
# Drop None rows in the category column
# null_category_idx = tweets['Category'].isna().index
tweets = tweets.dropna()

# %%
# Reset the tweets index
tweets = tweets.reset_index(drop=True)

# %%
tweets.head()
# Out:
#                     ID                                              Tweet  \
# 0  384275270082887680'  RT @AQpk: RT @313syiSitak: #YFK volunteers sha...
# 1  383596911598768128'  RT @CNBCPAKISTAN: Minister of State Sheikh Aft...
# 2  384041956038303744'  RT @kkfpk: Pic-9 #KKF send relief goods for #B...
# 3  384607507382935552'  RT @AnasMallick: Day 7th and some parts of Bal...
# 4  383487691297284098'  Field Mecical Camps and lady doctors are also ...
#
#                                                Label  \
# 0  donation_needs_or_offers_or_volunteering_services
# 1                             injured_or_dead_people
# 2  donation_needs_or_offers_or_volunteering_services
# 3  donation_needs_or_offers_or_volunteering_services
# 4  donation_needs_or_offers_or_volunteering_services
#
#                        Category
# 0  Relief Request and Donations
# 1                      Casualty
# 2  Relief Request and Donations
# 3  Relief Request and Donations
# 4  Relief Request and Donations

# %%
# Look at the count of unique values in the category column
tweets['Category'].value_counts()
# Out:
# Casualty                        7465
# Sympathy and Support            7043
# Relief Request and Donations    6227
# Caution and Advice              4077
# Damage Report                   3918
# Search and Rescue               1126
# Name: Category, dtype: int64

# %%
tweets.shape
# Out:
# (29856, 4)

# %%
# Drop the Label column
tweets = tweets.drop('Label', axis=1)

# %%
tweets.shape
# Out:
# (29856, 3)

# %%
tweets.head()
# Out:
#                     ID                                              Tweet  \
# 0  384275270082887680'  RT @AQpk: RT @313syiSitak: #YFK volunteers sha...
# 1  383596911598768128'  RT @CNBCPAKISTAN: Minister of State Sheikh Aft...
# 2  384041956038303744'  RT @kkfpk: Pic-9 #KKF send relief goods for #B...
# 3  384607507382935552'  RT @AnasMallick: Day 7th and some parts of Bal...
# 4  383487691297284098'  Field Mecical Camps and lady doctors are also ...
#
#                        Category
# 0  Relief Request and Donations
# 1                      Casualty
# 2  Relief Request and Donations
# 3  Relief Request and Donations
# 4  Relief Request and Donations

# %%
# Save mapped tweets to file
tweets.to_csv(os.path.join(data_dir, "Mapped_Tweets.csv"), index=False)

# %% [markdown]
# ## **Data Preprocessing**

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
    
# nltk.download('stopwords')
nltk.download('wordnet')
# nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Kelvin
# [nltk_data]     Chumbe\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
STOPWORDS = stopwords.words('english')

# %%
# Dictionary mapping word contractions to their full words
contractions = { 
    "ain't": "are not","'s":" is","aren't": "are not",
     "can't": "cannot","can't've": "cannot have",
     "'cause": "because","could've": "could have","couldn't": "could not",
     "couldn't've": "could not have", "didn't": "did not","doesn't": "does not",
     "don't": "do not","hadn't": "had not","hadn't've": "had not have",
     "hasn't": "has not","haven't": "have not","he'd": "he would",
     "he'd've": "he would have","he'll": "he will", "he'll've": "he will have",
     "how'd": "how did","how'd'y": "how do you","how'll": "how will",
     "I'd": "I would", "I'd've": "I would have","I'll": "I will",
     "I'll've": "I will have","I'm": "I am","I've": "I have", "isn't": "is not",
     "it'd": "it would","it'd've": "it would have","it'll": "it will",
     "it'll've": "it will have", "let's": "let us","ma'am": "madam",
     "mayn't": "may not","might've": "might have","mightn't": "might not", 
     "mightn't've": "might not have","must've": "must have","mustn't": "must not",
     "mustn't've": "must not have", "needn't": "need not",
     "needn't've": "need not have","o'clock": "of the clock","oughtn't": "ought not",
     "oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not",
     "shan't've": "shall not have","she'd": "she would","she'd've": "she would have",
     "she'll": "she will", "she'll've": "she will have","should've": "should have",
     "shouldn't": "should not", "shouldn't've": "should not have","so've": "so have",
     "that'd": "that would","that'd've": "that would have", "there'd": "there would",
     "there'd've": "there would have", "they'd": "they would",
     "they'd've": "they would have","they'll": "they will",
     "they'll've": "they will have", "they're": "they are","they've": "they have",
     "to've": "to have","wasn't": "was not","we'd": "we would",
     "we'd've": "we would have","we'll": "we will","we'll've": "we will have",
     "we're": "we are","we've": "we have", "weren't": "were not","what'll": "what will",
     "what'll've": "what will have","what're": "what are", "what've": "what have",
     "when've": "when have","where'd": "where did", "where've": "where have",
     "who'll": "who will","who'll've": "who will have","who've": "who have",
     "why've": "why have","will've": "will have","won't": "will not",
     "won't've": "will not have", "would've": "would have","wouldn't": "would not",
     "wouldn't've": "would not have","y'all": "you all", "y'all'd": "you all would",
     "y'all'd've": "you all would have","y'all're": "you all are",
     "y'all've": "you all have", "you'd": "you would","you'd've": "you would have",
     "you'll": "you will","you'll've": "you will have", "you're": "you are",
     "you've": "you have"
}

# %% [markdown]
# SAMPLE TWEET
#
#     'RT @AQpk: RT @313syiSitak: #YFK volunteers share their views on #Kashmir with Farah in her live Morning Show on #ATV http://t.co/alLPKCLeDy…'

# %%
# Remove punctutation marks, stopwords, emojis, urls, convert to lowercase, expand contractions, hashtags, retweet
def preprocess_tweet(tweet):
    res_tweet = []
    lemmatizer = WordNetLemmatizer()
    
    for word in tweet.split():        
        
        # Expand Contractions
        word = contractions.get(word.lower(), word)
        
        # Remove stopwords
        if word not in STOPWORDS:
            
            # Remove url
            word = re.sub(r'http\S+', '', word)
            
            # Remove usernames
            word = re.sub('@[\w]+','',word)
            
            # Remove hashtag
            word = re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", '', word)         # Remove hashtag symbol
#             word = re.sub(r'#[\w]+', '', word)           # Remove hashtag symbol and text
    
            emoji_clean= re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
            word = emoji_clean.sub(r'', word)
            
             # Remove punctuation
            word = re.sub(r'[^\w\s]', '', word)
                        
            # Remove Retweet
            word = re.sub(r'RT', '', word)
            
            # Convert to lowercase
            word = word.lower()
            
            # Lemmatize the word
            word = lemmatizer.lemmatize(word, pos='v')
        
            if word != '':
                res_tweet.append(word)
    

    return ' '.join([word for word in res_tweet])

# %%
tweets['Tweet'] = tweets['Tweet'].apply(lambda x: preprocess_tweet(x))

# %%
tweets.head()
# Out:
#                     ID                                              Tweet  \
# 0  384275270082887680'  yfk volunteer share view kashmir farah live mo...
# 1  383596911598768128'  minister state sheikh aftab 9 soldier 4 civili...
# 2  384041956038303744'  pic9 kkf send relief goods balochistan earthqu...
# 3  384607507382935552'  day 7th part balochistan hit earthquake yet re...
# 4  383487691297284098'  field mecical camp lady doctor also reach eart...
#
#                        Category
# 0  Relief Request and Donations
# 1                      Casualty
# 2  Relief Request and Donations
# 3  Relief Request and Donations
# 4  Relief Request and Donations

# %%
# Save preprocessed tweets to file
tweets.to_csv(os.path.join(data_dir,'Preprocessed_tweets.csv'), index=False)

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
# Look at the distribution of categories in the tweets
fig = plt.figure(figsize=(7,5))
ax = fig.gca()
tweets['Category'].value_counts().plot(kind='bar', ax=ax)
# Out:
# <AxesSubplot:>

# %%
category_dist = pd.DataFrame(data=tweets['Category'].value_counts(), columns=['Category'])
category_dist = category_dist.rename(columns={
    'Category': 'Count'
})
category_dist['Percentage of Total'] = category_dist['Count'] / tweets.shape[0]
category_dist
# Out:
#                               Count  Percentage of Total
# Casualty                       7465             0.250033
# Sympathy and Support           7043             0.235899
# Relief Request and Donations   6227             0.208568
# Caution and Advice             4077             0.136555
# Damage Report                  3918             0.131230
# Search and Rescue              1126             0.037714

# %% [markdown]
# #### **Observations**
# * The distribution of categories is quite imbalanced with Search and Rescue being about 3% of all the tweets

# %% [markdown]
# ### **Analysis to Consider**
# The meta features used for the analysis are;
#
# * word_count number of words in text
# * unique_word_count number of unique words in text
# * stop_word_count number of stop words in text
# * url_count number of urls in text
# * mean_word_length average character count in words
# * char_count number of characters in text
# * punctuation_count number of punctuations in text
# * hashtag_count number of hashtags (#) in text
# * mention_count number of mentions (@) in text

# %%
from nltk.probability import FreqDist

# %%
tweet_tokens = [word for tweet in tweets['Tweet'] for word in tweet.split()]
fdist = FreqDist(tweet_tokens)

# %%
fig = plt.figure(figsize=(14,8))
ax = fig.gca()

pd.Series(dict(fdist.most_common(30))).plot(kind='bar', ax=ax)
# Out:
# <AxesSubplot:>

# %%
for category in tweets['Category'].unique():
    tweet_tokens = [word for tweet in tweets[tweets['Category'] == category]['Tweet'] for word in tweet.split()]
    fdist = FreqDist(tweet_tokens)
    
    fig = plt.figure(figsize=(14,8))
    ax = fig.gca()

    pd.Series(dict(fdist.most_common(30))).plot(kind='bar', ax=ax)
    plt.title('Most common words in ' + category + ' category')

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
def display_cloud(label):
    plt.subplots(figsize=(10,10))
    text = tweets[tweets['Category']==label]["Tweet"].tolist()
    wc = WordCloud(
      stopwords=STOPWORDS,
      background_color='white',
      colormap='Blues',
      collocations=False,
      width=1800,
      height=800,
    )
    wc.generate(' '.join(text))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis('off')
    plt.title(label,fontsize=24)
    plt.show()

# %%
for category in tweets['Category'].unique():
    display_cloud(category)

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.gca() 
    
tweets['Tweet'].str.len().hist(bins=20, ax=ax)
# Out:
# <AxesSubplot:>

# %%
for category in tweets['Category'].unique():
    fig = plt.figure(figsize=(10,7))
    ax = fig.gca()
    
    tweets[tweets['Category'] == category]['Tweet'].str.len().hist(bins=20, ax=ax)
    plt.title(category)

# %%
from nltk.util import ngrams

# %%
for category in tweets['Category'].unique():
    tweet_tokens = [word for tweet in tweets[tweets['Category'] == category]['Tweet'] for word in tweet.split()]
    token_grams = ngrams(tweet_tokens, 2)
    fdist = FreqDist(token_grams)
    
    fig = plt.figure(figsize=(14,8))
    ax = fig.gca()

    pd.Series(dict(fdist.most_common(30))).plot(kind='bar', ax=ax)
    plt.title('Bigrams in ' + category + ' category')

# %%
for category in tweets['Category'].unique():
    tweet_tokens = [word for tweet in tweets[tweets['Category'] == category]['Tweet'] for word in tweet.split()]
    token_grams = ngrams(tweet_tokens, 3)
    fdist = FreqDist(token_grams)
    
    fig = plt.figure(figsize=(12,14))
    ax = fig.gca()

    pd.Series(dict(fdist.most_common(30))).plot(kind='barh', ax=ax)
    plt.title('Trigrams in ' + category + ' category')
